# %%
import matplotlib.pyplot as plt  
import numpy as np
import os                        
import shutil                    
from tensorflow import keras
import seaborn as sns
import random
from keras.models import load_model
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import load_img, img_to_array
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
current_dir = os.getcwd()
print(current_dir)
# Out:
# /kaggle/working

# %%
dristhi_dir = '/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/Drishti-GS1'
train_glaucoma_dir ="/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/Drishti-GS1/Glaucoma"
train_normal_dir ="/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/Drishti-GS1/Normal"
dristhi_glaucoma_images = os.listdir(train_glaucoma_dir)
dristhi_normal_images = os.listdir(train_normal_dir)
# Look at the number of samples in each dataset
print("Dristhi dataset contains :")
print(f"\t{len(dristhi_glaucoma_images)} images representing an eye with glaucoma")
print(f"\t{len(dristhi_normal_images)} images representing a normal eye")
# Out:
# Dristhi dataset contains :
# 	3000 images representing an eye with glaucoma
# 	3000 images representing a normal eye

# %%
print("Sample Dristhi glaucoma images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(train_glaucoma_dir, dristhi_glaucoma_images[i - 1])}"))
plt.show()

print("\nSample Dristhi normal images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(train_normal_dir, dristhi_normal_images[i - 1])}"))
plt.show()
# Out:
# Sample Dristhi glaucoma images:
# /tmp/ipykernel_28/61996552.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)
# Sample Dristhi normal images:
# /tmp/ipykernel_28/61996552.py:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)

# %%
rimOne_dir ='/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/Rim-One'
train_glaucoma_dir = "/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/Rim-One/Glaucoma"
train_normal_dir = "/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/Rim-One/Normal"
rimOne_glaucoma_images = os.listdir(train_glaucoma_dir)
rimOne_normal_images = os.listdir(train_normal_dir)

# Look at the number of samples in each dataset
print("Rim One dataset contains :")
print(f"\t{len(rimOne_glaucoma_images)} images representing an eye with glaucoma")
print(f"\t{len(rimOne_normal_images)} images representing a normal eye")
# Out:
# Rim One dataset contains :
# 	3000 images representing an eye with glaucoma
# 	3000 images representing a normal eye

# %%
print("Sample Rim-One glaucoma images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(train_glaucoma_dir, rimOne_glaucoma_images[i - 1])}"))
plt.show()

print("\nSample Rim-One normal images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(train_normal_dir, rimOne_normal_images[i - 1])}"))
plt.show()
# Out:
# Sample Rim-One glaucoma images:
# /tmp/ipykernel_28/3177373283.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)
# Sample Rim-One normal images:
# /tmp/ipykernel_28/3177373283.py:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)

# %%
acrima_dir ="/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/Acrima"
glaucoma_dir = acrima_dir + "/Glaucoma"
normal_dir = acrima_dir + "/Normal"

normal_images = os.listdir(normal_dir)
glaucoma_images = os.listdir(glaucoma_dir)

# Look at the number of samples in each dataset
print("Acrima dataset contains : ")
print(f"\t{len(glaucoma_images)} images representing an eye with glaucoma")
print(f"\t{len(normal_images)} images representing a normal eye")
# Out:
# Acrima dataset contains :
# 	3000 images representing an eye with glaucoma
# 	3000 images representing a normal eye

# %%
print("Sample glaucoma images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(glaucoma_dir, glaucoma_images[i - 1])}"))
plt.show()

print("\nSample normal images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(normal_dir, normal_images[i - 1])}"))
plt.show()
# Out:
# Sample glaucoma images:
# /tmp/ipykernel_28/2410014847.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)
# Sample normal images:
# /tmp/ipykernel_28/2410014847.py:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)

# %%
os.mkdir('/kaggle/working/Combine1')
## define your paths for glaucoma####
g_path1 = '/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/Drishti-GS1/Glaucoma'
g_path2 = '/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/Rim-One/Glaucoma'
g_path3 ='/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/Drishti-GS1/Glaucoma'
g_dest='/kaggle/working/Combine1/glaucoma'

os.mkdir(g_dest)
g_list=[g_path1,g_path2,g_path3]

for i in g_list:
  shutil.copytree(i, g_dest, dirs_exist_ok=True)
print(len(os.listdir('/kaggle/working/Combine1/glaucoma')))

##################################################
#normal
n_path1='/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/Acrima/Normal'
n_path2='/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/Drishti-GS1/Normal'
n_path3='/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/Rim-One/Normal'
n_dest='/kaggle/working/Combine1/normal'
os.mkdir(n_dest)
n_list=[n_path1,n_path2,n_path3]

for i in n_list:
  shutil.copytree(i,n_dest, dirs_exist_ok=True)
print(len(os.listdir(n_dest)))
# Out:
# 6000
# 8402

# %%
import pathlib

base_dir = '/kaggle/working/Combine1'
base_dir = pathlib.Path(base_dir)

glaucoma = [fn for fn in os.listdir(f'/kaggle/working/Combine1/glaucoma/')]
normal = [fn for fn in os.listdir(f'/kaggle/working/Combine1/normal')]
data=[glaucoma,normal]
dataset_classes =['glaucoma','normal']

image_count = len(list(base_dir.glob('*/*.jpg')))+len(list(base_dir.glob('*/*.png')))
print(f'Total images: {image_count}')
print(f'Total number of classes: {len(dataset_classes)}')
count = 0
data_count = []
for x in dataset_classes:
  print(f'Total {x} images: {len(data[count])}')
  data_count.append(len(data[count]))
  count += 1

sns.set_style('darkgrid')
sns.barplot(x=dataset_classes, y=data_count)
plt.show()
# Out:
# Total images: 14402
# Total number of classes: 2
# Total glaucoma images: 6000
# Total normal images: 8402

# %%
# !pip install split-folders 
import splitfolders #to split dataset
import pathlib
base_ds = '/kaggle/working/Combine1'
base_ds = pathlib.Path(base_ds)
img_height=256
img_width=256
batch_size=32
splitfolders.ratio(base_ds, output='images', seed=1321, ratio=(.8,.1,.1), group_prefix=None)
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Copying files: 14402 files [00:02, 6917.50 files/s]

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rescale=1./255,
shear_range = 0.15,
zoom_range = 0.15,
horizontal_flip = True)
train_ds = datagen.flow_from_directory(
    'images/train',
    target_size = (img_height, img_width),
    batch_size = batch_size,
    class_mode='categorical',
    shuffle=False)

val_ds = datagen.flow_from_directory(
    'images/val',
    target_size = (img_height, img_width),
    batch_size = batch_size,
    class_mode='categorical',
    shuffle=False)

test_ds = datagen.flow_from_directory(
    'images/test',
    target_size = (img_height, img_width),
    batch_size = batch_size,
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 11521 images belonging to 2 classes.
# Found 1440 images belonging to 2 classes.
# Found 1441 images belonging to 2 classes.

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense,Dropout
from keras.layers import BatchNormalization

# Initialising the CNN
classifier = Sequential()
# Step 1 - Adding Convolution layer
classifier.add(Conv2D(32, (3, 3), input_shape = (256,256, 3), activation = 'relu'))

# Step 2 - Adding MaxPooling layers
classifier.add(MaxPooling2D(pool_size = (2, 2)))
# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 512, activation = 'relu'))
classifier.add(BatchNormalization()),
classifier.add(Dense(256,activation='relu')),
classifier.add(Dropout(0.25)),
classifier.add(Dense(units = 2, activation = 'softmax'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 123008)            0
#
#  dense (Dense)               (None, 512)               62980608
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 63,124,642
# Trainable params: 63,123,618
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
model_info=classifier.fit(train_ds,
steps_per_epoch = int(round(1032/32)),
epochs = 50,
validation_data = val_ds,
validation_steps = int(round(128/32)))
# Out:
# Epoch 1/50
# 32/32 [==============================] - 18s 565ms/step - loss: 0.8097 - accuracy: 0.5977 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 2/50
# 32/32 [==============================] - 18s 566ms/step - loss: 0.6574 - accuracy: 0.6543 - val_loss: 10.0131 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 32/32 [==============================] - 18s 567ms/step - loss: 0.5912 - accuracy: 0.7012 - val_loss: 15.5446 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 32/32 [==============================] - 17s 539ms/step - loss: 0.6547 - accuracy: 0.7158 - val_loss: 13.3824 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 32/32 [==============================] - 18s 564ms/step - loss: 0.6938 - accuracy: 0.6729 - val_loss: 3.7649 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 32/32 [==============================] - 20s 623ms/step - loss: 0.5802 - accuracy: 0.6826 - val_loss: 0.9924 - val_accuracy: 0.4844
# Epoch 7/50
# 32/32 [==============================] - 18s 549ms/step - loss: 0.6403 - accuracy: 0.6895 - val_loss: 0.1572 - val_accuracy: 0.9141
# Epoch 8/50
# 32/32 [==============================] - 18s 567ms/step - loss: 0.4955 - accuracy: 0.7510 - val_loss: 0.0308 - val_accuracy: 1.0000
# Epoch 9/50
# 32/32 [==============================] - 17s 543ms/step - loss: 0.3943 - accuracy: 0.8174 - val_loss: 0.2118 - val_accuracy: 0.9219
# Epoch 10/50
# 32/32 [==============================] - 18s 570ms/step - loss: 0.3434 - accuracy: 0.8379 - val_loss: 1.0571 - val_accuracy: 0.3438
# Epoch 11/50
# 32/32 [==============================] - 17s 535ms/step - loss: 0.3989 - accuracy: 0.8105 - val_loss: 0.4734 - val_accuracy: 0.6953
# Epoch 12/50
# 32/32 [==============================] - 18s 562ms/step - loss: 0.3908 - accuracy: 0.8037 - val_loss: 0.6125 - val_accuracy: 0.6406
# Epoch 13/50
# 32/32 [==============================] - 17s 541ms/step - loss: 0.3120 - accuracy: 0.8477 - val_loss: 0.5224 - val_accuracy: 0.7422
# Epoch 14/50
# 32/32 [==============================] - 17s 544ms/step - loss: 0.4215 - accuracy: 0.8157 - val_loss: 1.7990 - val_accuracy: 0.3203
# Epoch 15/50
# 32/32 [==============================] - 16s 513ms/step - loss: 0.3996 - accuracy: 0.7891 - val_loss: 0.3003 - val_accuracy: 0.8516
# Epoch 16/50
# 32/32 [==============================] - 18s 563ms/step - loss: 0.3547 - accuracy: 0.8389 - val_loss: 0.5706 - val_accuracy: 0.6719
# Epoch 17/50
# 32/32 [==============================] - 18s 568ms/step - loss: 0.2822 - accuracy: 0.8906 - val_loss: 0.9776 - val_accuracy: 0.4609
# Epoch 18/50
# 32/32 [==============================] - 18s 549ms/step - loss: 0.2979 - accuracy: 0.8711 - val_loss: 0.4106 - val_accuracy: 0.7812
# Epoch 19/50
# 32/32 [==============================] - 18s 556ms/step - loss: 0.2226 - accuracy: 0.9150 - val_loss: 0.8279 - val_accuracy: 0.3906
# Epoch 20/50
# 32/32 [==============================] - 18s 558ms/step - loss: 0.1391 - accuracy: 0.9482 - val_loss: 0.4603 - val_accuracy: 0.7422
# Epoch 21/50
# 32/32 [==============================] - 18s 551ms/step - loss: 0.3134 - accuracy: 0.8779 - val_loss: 0.2186 - val_accuracy: 0.9297
# Epoch 22/50
# 32/32 [==============================] - 18s 559ms/step - loss: 0.3256 - accuracy: 0.8438 - val_loss: 0.0850 - val_accuracy: 0.9922
# Epoch 23/50
# 32/32 [==============================] - 17s 523ms/step - loss: 0.2240 - accuracy: 0.9121 - val_loss: 0.4792 - val_accuracy: 0.7891
# Epoch 24/50
# 32/32 [==============================] - 18s 552ms/step - loss: 0.1705 - accuracy: 0.9345 - val_loss: 0.1691 - val_accuracy: 0.9766
# Epoch 25/50
# 32/32 [==============================] - 17s 522ms/step - loss: 0.2548 - accuracy: 0.8984 - val_loss: 0.2216 - val_accuracy: 0.9453
# Epoch 26/50
# 32/32 [==============================] - 17s 548ms/step - loss: 0.2531 - accuracy: 0.8965 - val_loss: 0.4024 - val_accuracy: 0.7734
# Epoch 27/50
# 32/32 [==============================] - 18s 572ms/step - loss: 0.2493 - accuracy: 0.9043 - val_loss: 0.5804 - val_accuracy: 0.6484
# Epoch 28/50
# 32/32 [==============================] - 17s 547ms/step - loss: 0.3056 - accuracy: 0.8789 - val_loss: 0.0813 - val_accuracy: 0.9844
# Epoch 29/50
# 32/32 [==============================] - 18s 572ms/step - loss: 0.2874 - accuracy: 0.8740 - val_loss: 0.4569 - val_accuracy: 0.7891
# Epoch 30/50
# 32/32 [==============================] - 17s 532ms/step - loss: 0.1384 - accuracy: 0.9512 - val_loss: 0.2733 - val_accuracy: 0.8984
# Epoch 31/50
# 32/32 [==============================] - 18s 557ms/step - loss: 0.1081 - accuracy: 0.9629 - val_loss: 0.6459 - val_accuracy: 0.6172
# Epoch 32/50
# 32/32 [==============================] - 19s 613ms/step - loss: 0.1719 - accuracy: 0.9385 - val_loss: 0.1005 - val_accuracy: 0.9531
# Epoch 33/50
# 32/32 [==============================] - 17s 537ms/step - loss: 0.1796 - accuracy: 0.9346 - val_loss: 1.4252 - val_accuracy: 0.3828
# Epoch 34/50
# 32/32 [==============================] - 17s 545ms/step - loss: 0.0614 - accuracy: 0.9824 - val_loss: 0.2817 - val_accuracy: 0.8828
# Epoch 35/50
# 32/32 [==============================] - 16s 513ms/step - loss: 0.1366 - accuracy: 0.9386 - val_loss: 1.0110 - val_accuracy: 0.5391
# Epoch 36/50
# 32/32 [==============================] - 18s 574ms/step - loss: 0.2138 - accuracy: 0.9092 - val_loss: 11.1678 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 32/32 [==============================] - 17s 528ms/step - loss: 0.2120 - accuracy: 0.9121 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 38/50
# 32/32 [==============================] - 18s 549ms/step - loss: 0.0791 - accuracy: 0.9736 - val_loss: 0.0512 - val_accuracy: 0.9844
# Epoch 39/50
# 32/32 [==============================] - 18s 547ms/step - loss: 0.0977 - accuracy: 0.9658 - val_loss: 0.2499 - val_accuracy: 0.8906
# Epoch 40/50
# 32/32 [==============================] - 17s 537ms/step - loss: 0.0957 - accuracy: 0.9619 - val_loss: 0.5978 - val_accuracy: 0.7266
# Epoch 41/50
# 32/32 [==============================] - 18s 551ms/step - loss: 0.1634 - accuracy: 0.9326 - val_loss: 0.2398 - val_accuracy: 0.8984
# Epoch 42/50
# 32/32 [==============================] - 17s 524ms/step - loss: 0.0749 - accuracy: 0.9795 - val_loss: 0.5920 - val_accuracy: 0.7656
# Epoch 43/50
# 32/32 [==============================] - 18s 559ms/step - loss: 0.1435 - accuracy: 0.9482 - val_loss: 1.0795 - val_accuracy: 0.4922
# Epoch 44/50
# 32/32 [==============================] - 17s 537ms/step - loss: 0.0402 - accuracy: 0.9893 - val_loss: 0.8372 - val_accuracy: 0.6562
# Epoch 45/50
# 32/32 [==============================] - 18s 559ms/step - loss: 0.1127 - accuracy: 0.9580 - val_loss: 0.1854 - val_accuracy: 0.8984
# Epoch 46/50
# 32/32 [==============================] - 18s 553ms/step - loss: 0.0955 - accuracy: 0.9648 - val_loss: 0.0273 - val_accuracy: 1.0000
# Epoch 47/50
# 32/32 [==============================] - 17s 526ms/step - loss: 0.1219 - accuracy: 0.9502 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 48/50
# 32/32 [==============================] - 18s 564ms/step - loss: 0.0914 - accuracy: 0.9727 - val_loss: 0.0348 - val_accuracy: 0.9844
# Epoch 49/50
# 32/32 [==============================] - 17s 520ms/step - loss: 0.0401 - accuracy: 0.9873 - val_loss: 0.0583 - val_accuracy: 0.9766
# Epoch 50/50
# 32/32 [==============================] - 18s 549ms/step - loss: 0.0660 - accuracy: 0.9707 - val_loss: 0.1115 - val_accuracy: 0.9688

# %%
def plot_train_history(history):
    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

plot_train_history(model_info)

# %%
def glaucoma_prediction(test_image):
  image = img_to_array(test_image)
  image = np.expand_dims(image, axis = 0)
  result = np.argmax(classifier.predict(image))
  return result

# %%
test_image = load_img('/kaggle/input/datasets-higancnn-glaucoma-detection/Datasets/HRF/Glaucoma/train-28774.png', target_size = (256,256))
prediction = glaucoma_prediction(test_image)
if prediction == 0:
 print("Glaucoma")
else:
 print("Not Glaucoma")
# Out:
# 1/1 [==============================] - 0s 119ms/step
# Glaucoma

# %%
score=classifier.evaluate(test_ds)
print("Loss:",score[0],"Accuracy:",score[1])
# Out:
# 46/46 [==============================] - 20s 424ms/step - loss: 0.2150 - accuracy: 0.9070
# Loss: 0.2150336056947708 Accuracy: 0.9070090055465698

# %%
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sb

pred= np.round(classifier.predict(test_ds, verbose=1))
test_labels=test_ds.labels
test_pred_labels=[]
for i in range(len(pred)):
  test_pred_labels.append(np.argmax(pred[i]))
conf_matrix= confusion_matrix(test_pred_labels,test_labels)
print(conf_matrix)


sb.heatmap(conf_matrix,cmap='Purples', annot=True,xticklabels=['glaucoma','normal'],yticklabels=['glaucoma','normal'],linewidths=1,
                linecolor='green').plot()
plt.show()
# Out:
# 46/46 [==============================] - 22s 479ms/step
# [[577 102]
#  [ 23 739]]

# %%
import pandas as pd
test_report = classification_report(test_ds.labels,test_pred_labels, target_names=['glaucoma','normal'], output_dict=True)
test_df = pd.DataFrame(test_report).transpose()
test_df
# Out:
#               precision    recall  f1-score      support
# glaucoma       0.867470  0.960000  0.911392   600.000000
# normal         0.969112  0.895363  0.930779   841.000000
# accuracy       0.922276  0.922276  0.922276     0.922276
# macro avg      0.918291  0.927681  0.921086  1441.000000
# weighted avg   0.926790  0.922276  0.922707  1441.000000
